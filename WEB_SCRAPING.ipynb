# %%
#web scraping - Extracting/Scraping data from the web
#Here let us scrape Amazon Customer reviews
#Tool used here is - Beautiful Soup

# %%
#url- https://www.amazon.in/Apple-iPhone-14-128GB-Blue/product-reviews/B0BDK62PDX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews

# %%
#we are importing different libraries
import requests
from bs4 import BeautifulSoup as bs

# %%
url= 'https://www.amazon.in/Apple-iPhone-14-128GB-Blue/product-reviews/B0BDK62PDX/ref=cm_cr_dp_d_show_all_btm?ie=UTF8&reviewerType=all_reviews'
page = requests.get(url)  #we are requesting for the url's web page
page


#<Response [503]> is an error, <Response [200]> is right
#try re running ur cell 5 - 10 times, if error exists then check ur url
# Out:
# <Response [200]>

# %%
page.content

# %%
#let us organize the above source code and print it in better readible format
soup=bs(page.content,'html.parser')
soup #html.parser is better readable format of source code

# %%
#never consider top positive and top critical reviews

# %%
#let us extract the Amazon customer review names
names = soup.find_all('span',class_ =  'a-profile-name')[2:] #a-profile-name is the inspected from the source code
names
# Out:
# [<span class="a-profile-name">Neeraj Singh</span>,
#  <span class="a-profile-name">Umang Dhanuka</span>,
#  <span class="a-profile-name">Kavita</span>,
#  <span class="a-profile-name">Ramesh Choudhary</span>,
#  <span class="a-profile-name">Ramesh Choudhary</span>,
#  <span class="a-profile-name">Subham Hazra</span>,
#  <span class="a-profile-name">Zoheb</span>,
#  <span class="a-profile-name">Subbarayudu</span>,
#  <span class="a-profile-name">Sushmita Sen Mazumder</span>]

# %%
len(names)  #variable names is a list and it has 9 elememts
# Out:
# 9

# %%
import pandas as pd
df = pd.DataFrame(names,columns = ['Customer Names'])
df
# Out:
#           Customer Names
# 0           Neeraj Singh
# 1          Umang Dhanuka
# 2                 Kavita
# 3       Ramesh Choudhary
# 4       Ramesh Choudhary
# 5           Subham Hazra
# 6                  Zoheb
# 7            Subbarayudu
# 8  Sushmita Sen Mazumder
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_9029713948635266718 = autoviz.get_df('df_9029713948635266718')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_9029713948635266718, *['Customer Names'], **{})
# chart
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.
# Error: Runtime no longer has a reference to this dataframe, please re-run this cell and try again.

# %%
df=df.drop_duplicates(ignore_index=True)
df
# Out:
#           Customer Names
# 0           Neeraj Singh
# 1          Umang Dhanuka
# 2                 Kavita
# 3       Ramesh Choudhary
# 4           Subham Hazra
# 5                  Zoheb
# 6            Subbarayudu
# 7  Sushmita Sen Mazumder
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4197901999148639430 = autoviz.get_df('df_4197901999148639430')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_4197901999148639430, *['Customer Names'], **{})
# chart
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
# df_4197901999148639430 = autoviz.get_df('df_4197901999148639430')
#
# def categorical_histogram(df, colname, figsize=(2, 1.2), mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   _, ax = plt.subplots(figsize=figsize)
#   bars = df[colname].value_counts()
#   plt.barh(bars.index, bars.values, color=sns.palettes.mpl_palette(mpl_palette_name))
#   plt.title(colname)
#   ax.spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(df_4197901999148639430, *['Customer Names'], **{})
# chart

# %%
#next let us just scrape the review title
r_title = soup.find_all('a',class_='review-title')
r_title

# %%
len(r_title)
# Out:
# 10

# %%
#Data filtering/ Daata cleaning
review_title = [] #emplty list
#for i  in range (0,10)
for i in range(0,len(r_title)):
  review_title.append(r_title[i].get_text())
review_title
# Out:
# ['5.0 out of 5 stars\nIt’s Apple after all, but don’t buy from Amazon\n',
#  '4.0 out of 5 stars\niPhone 14 and 14 pro max has different chipsets\n',
#  '4.0 out of 5 stars\nSame day delivery\n',
#  '5.0 out of 5 stars\nFeatures, Quality\n',
#  '5.0 out of 5 stars\nAwesome\n',
#  '5.0 out of 5 stars\niPhone is best\n',
#  '5.0 out of 5 stars\nGreat\n',
#  '4.0 out of 5 stars\nIts ok\n',
#  '5.0 out of 5 stars\nAs expected\n',
#  '5.0 out of 5 stars\niPhone 14 ….why one must go for it..\n']

# %%
#next is review date
dates = soup.find_all('span',class_='review-date')
dates
# Out:
# [<span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 18 July 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 4 July 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 13 June 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 18 July 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 18 July 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 30 June 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 12 July 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 31 May 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 6 July 2023</span>,
#  <span class="a-size-base a-color-secondary review-date" data-hook="review-date">Reviewed in India 🇮🇳 on 28 June 2023</span>]

# %%
len(dates)
# Out:
# 10

# %%
#Data filtering/ Daata cleaning
review_date = [] #emplty list
#for i  in range (0,10)
for i in range(0,len(dates)):
  review_date.append(dates[i].get_text().replace('Reviewed in India 🇮🇳 on',''))
review_date
# Out:
# [' 18 July 2023',
#  ' 4 July 2023',
#  ' 13 June 2023',
#  ' 18 July 2023',
#  ' 18 July 2023',
#  ' 30 June 2023',
#  ' 12 July 2023',
#  ' 31 May 2023',
#  ' 6 July 2023',
#  ' 28 June 2023']
